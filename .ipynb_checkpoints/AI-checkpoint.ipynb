# %%
# Thêm thư viện
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
from IPython.core.display import HTML
import matplotlib.pyplot as plt
from scipy.stats import uniform

# %%
# đọc dữ liệu
df = pd.read_csv('heart.csv')
print('Shape of the data is ', df.shape)
# Out:
# Shape of the data is  (303, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.target.value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
sns.countplot(x="target", data=df)
plt.xlabel(" 1 = Có bệnh, 0= Không có bệnh)")
plt.show()

# %%
countNoDisease = len(df[df.target == 0])
countHaveDisease = len(df[df.target == 1])
print("Phần trăm bệnh nhân không có bệnh tim: {:.2f}%".format((countNoDisease / (len(df.target))*100)))
print("Phần trăm bệnh nhân có bệnh tim: {:.2f}%".format((countHaveDisease / (len(df.target))*100)))
# Out:
# Phần trăm bệnh nhân không có bệnh tim: 45.54%
# Phần trăm bệnh nhân có bệnh tim: 54.46%

# %%
sns.countplot(x='sex', data=df)
plt.xlabel("Giới tính (0 = Nữ, 1= Nam)")
plt.show()

# %%
countFemale = len(df[df.sex == 0])
countMale = len(df[df.sex == 1])
print("Phần trăm bệnh nhân nữ: {:.2f}%".format((countFemale / (len(df.sex))*100)))
print("Phần trăm bệnh nhân nam: {:.2f}%".format((countMale / (len(df.sex))*100)))
# Out:
# Phần trăm bệnh nhân nữ: 31.68%
# Phần trăm bệnh nhân nam: 68.32%

# %%
df.groupby('target').mean()
# Out:
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.601449  0.826087  0.478261  134.398551  251.086957  0.159420
# 1       52.496970  0.563636  1.375758  129.303030  242.230303  0.139394
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.449275  139.101449  0.550725  1.585507  1.166667  1.166667  2.543478
# 1       0.593939  158.466667  0.139394  0.583030  1.593939  0.363636  2.121212

# %%
pd.crosstab(df.age,df.target).plot(kind="bar",figsize=(20,6))
plt.title('Tỷ lệ phần trăm bệnh tim theo tuổi')
plt.xlabel('Tuổi')
plt.ylabel('Số người')
#plt.savefig('phantramtheotuoi.png')
plt.show()

# %%
print(pd.crosstab(df.sex,df.target))
pd.crosstab(df.sex,df.target).plot(kind="bar",figsize=(15,6))
plt.title('Tỷ lệ bệnh tim theo giới tính')
plt.xlabel('Giới tính (0 = Nữ, 1 = Nam)')
plt.xticks(rotation=0)
plt.legend(["Chưa có bệnh", "Có bệnh"])
plt.ylabel('Số người')
plt.show()
# Out:
# target    0   1
# sex
# 0        24  72
# 1       114  93

# %%
print(pd.crosstab(df.age,df.sex))
pd.crosstab(df.age,df.sex).plot(kind="bar",figsize=(15,6))
plt.title('Tỷ lệ giới tính theo độ tuổi')
plt.xlabel('Độ tuổi')
plt.xticks(rotation=0)
plt.legend(["Nữ", "Nam"])
plt.ylabel('Số người')
plt.show()
# Out:
# sex  0   1
# age
# 29   0   1
# 34   1   1
# 35   1   3
# 37   1   1
# 38   0   3
# 39   2   2
# 40   0   3
# 41   4   6
# 42   2   6
# 43   2   6
# 44   2   9
# 45   3   5
# 46   3   4
# 47   0   5
# 48   1   6
# 49   2   3
# 50   3   4
# 51   4   8
# 52   1  12
# 53   3   5
# 54   5  11
# 55   4   4
# 56   3   8
# 57   4  13
# 58   6  13
# 59   1  13
# 60   4   7
# 61   2   6
# 62   7   4
# 63   5   4
# 64   3   7
# 65   4   4
# 66   3   4
# 67   3   6
# 68   1   3
# 69   1   2
# 70   0   4
# 71   3   0
# 74   1   0
# 76   1   0
# 77   0   1

# %%
plt.scatter(x=df.age[df.target==1], y=df.thalach[(df.target==1)], c="red")
plt.scatter(x=df.age[df.target==0], y=df.thalach[(df.target==0)])
plt.legend(["Có bệnh", "Không có bệnh"])
plt.xlabel("Tuổi")
plt.ylabel("Nhịp tim tối đa")
plt.show()

# %%
print(pd.crosstab(df.slope,df.target))
pd.crosstab(df.slope,df.target).plot(kind="bar",figsize=(15,6))
plt.title('Tỷ lệ bệnh tim theo độ dốc')
plt.xlabel('Độ dốc của bài tập Segment ')
plt.xticks(rotation = 0)
plt.ylabel('Số người')
plt.show()
# Out:
# target   0    1
# slope
# 0       12    9
# 1       91   49
# 2       35  107

# %%
print(pd.crosstab(df.fbs,df.target))
pd.crosstab(df.fbs,df.target).plot(kind="bar",figsize=(15,6))
plt.title('Tỷ lệ bệnh tim theo FBS')
plt.xlabel('FBS - (Lượng đường trong máu > 120 mg/dL) (1 = Đúng; 0 = Sai)')
plt.xticks(rotation = 0)
plt.legend(["Chưa có bệnh", "Có bệnh"])
plt.ylabel('Số người')
plt.show()
# Out:
# target    0    1
# fbs
# 0       116  142
# 1        22   23

# %%
print(pd.crosstab(df.cp,df.target))
pd.crosstab(df.cp,df.target).plot(kind="bar",figsize=(15,6))
plt.title('Tỷ lệ phần trăm bệnh tim theo loại đau ngực')
plt.xlabel('Loại đau ngực')
print(" 0 = Đau thắt ngực điển hình\n","1 = Đau thắt ngực không điển hình\n","2 = Không đau thắt ngực\n","3 = Không có triệu chứng\n")
plt.xticks(rotation = 0)
plt.ylabel('Số người')
plt.show()
# Out:
# target    0   1
# cp
# 0       104  39
# 1         9  41
# 2        18  69
# 3         7  16
#  0 = Đau thắt ngực điển hình
#  1 = Đau thắt ngực không điển hình
#  2 = Không đau thắt ngực
#  3 = Không có triệu chứng
